# %%
import numpy as np
import pandas as pd
from nanoporePipelineCommon import NanoJAMDF, SamOrBamFile, pick_libs_return_paths_dict, pick_lib_return_path
pd.set_option('display.width', 100)
pd.set_option('display.max_columns', None)
print("imports done.")
# Out:
# imports done.

# %%
lib_to_test = "totalRNA3"
nano_jam_path = pick_lib_return_path(lib_to_test)
bam_path = pick_lib_return_path(lib_to_test, output_dir_folder="cat_files",
                                file_midfix=".sorted.mappedAndPrimary",
                                file_suffix="bam")
# Out:
# Looking for file for totalRNA3, at /data16/marcus/working/220131_nanoporeRun_totalRNA_0639_L3_third/output_dir/merge_files/*_mergedOnReads.parquet... File Found.
# Looking for file for totalRNA3, at /data16/marcus/working/220131_nanoporeRun_totalRNA_0639_L3_third/output_dir/cat_files/*.sorted.mappedAndPrimary.bam... File Found.

# %%
bam_obj = SamOrBamFile(bam_path)
nano_jam_df = pd.read_parquet(nano_jam_path)
# Out:
# 03/15/22 @ 02:37:47 PM: Starting to load bam file from: /data16/marcus/working/220131_nanoporeRun_totalRNA_0639_L3_third/output_dir/cat_files/cat.sorted.mappedAndPrimary.bam
# Processing fd82b4b7-176d-4ec6-a24f-3c8a58d999b4:   0%|          | 2835/1234635 [00:01<07:51, 2609.95it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processing 0332d8c1-6fa1-4f00-b145-ed2920a372a0:   1%|          | 11458/1234635 [00:04<07:22, 2767.27it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# ...
